# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# # EDA

# %% [markdown]
# ## Read data

# %%
df = pd.read_csv('/kaggle/input/fifa-world-cup-winners/WorldCups - WorldCups.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            21 non-null     int64
#  1   Country         21 non-null     object
#  2   Winner          21 non-null     object
#  3   Runners-Up      21 non-null     object
#  4   Third           21 non-null     object
#  5   Fourth          21 non-null     object
#  6   GoalsScored     21 non-null     int64
#  7   QualifiedTeams  21 non-null     int64
#  8   MatchesPlayed   21 non-null     int64
# dtypes: int64(4), object(5)
# memory usage: 1.6+ KB

# %%
df
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# 14  1994           USA      Brazil           Italy       Sweden
# 15  1998        France      France          Brazil      Croatia
# 16  2002   Korea/Japan      Brazil         Germany       Turkey
# 17  2006       Germany       Italy          France      Germany
# 18  2010  South Africa       Spain     Netherlands      Germany
# 19  2014        Brazil     Germany       Argentina  Netherlands
# 20  2018        Russia      France         Croatia      Belgium
#
#             Fourth  GoalsScored  QualifiedTeams  MatchesPlayed
# 0       Yugoslavia           70              13             18
# 1          Austria           70              16             17
# 2           Sweden           84              15             18
# 3            Spain           88              13             22
# 4          Uruguay          140              16             26
# 5       Germany FR          126              16             35
# 6       Yugoslavia           89              16             32
# 7     Soviet Union           89              16             32
# 8          Uruguay           95              16             32
# 9           Brazil           97              16             38
# 10           Italy          102              16             38
# 11          France          146              24             52
# 12         Belgium          132              24             52
# 13         England          115              24             52
# 14        Bulgaria          141              24             52
# 15     Netherlands          171              32             64
# 16  Korea Republic          161              32             64
# 17        Portugal          147              32             64
# 18         Uruguay          145              32             64
# 19          Brazil          171              32             64
# 20         England          169              32             64

# %% [markdown]
# ## Replace Data
# #### I replaced Germany FR with Germany because the Federal Republic of Germany was admitted to the United Nations on September 18, 1973. Through the accession of the German Democratic Republic (1990), the two German States united to form one sovereign State, Germany.

# %%
df = df.replace('Germany FR', 'Germany', regex=True)

df
# Out:
#     Year       Country     Winner      Runners-Up        Third  \
# 0   1930       Uruguay    Uruguay       Argentina          USA
# 1   1934         Italy      Italy  Czechoslovakia      Germany
# 2   1938        France      Italy         Hungary       Brazil
# 3   1950        Brazil    Uruguay          Brazil       Sweden
# 4   1954   Switzerland    Germany         Hungary      Austria
# 5   1958        Sweden     Brazil          Sweden       France
# 6   1962         Chile     Brazil  Czechoslovakia        Chile
# 7   1966       England    England         Germany     Portugal
# 8   1970        Mexico     Brazil           Italy      Germany
# 9   1974       Germany    Germany     Netherlands       Poland
# 10  1978     Argentina  Argentina     Netherlands       Brazil
# 11  1982         Spain      Italy         Germany       Poland
# 12  1986        Mexico  Argentina         Germany       France
# 13  1990         Italy    Germany       Argentina        Italy
# 14  1994           USA     Brazil           Italy       Sweden
# 15  1998        France     France          Brazil      Croatia
# 16  2002   Korea/Japan     Brazil         Germany       Turkey
# 17  2006       Germany      Italy          France      Germany
# 18  2010  South Africa      Spain     Netherlands      Germany
# 19  2014        Brazil    Germany       Argentina  Netherlands
# 20  2018        Russia     France         Croatia      Belgium
#
#             Fourth  GoalsScored  QualifiedTeams  MatchesPlayed
# 0       Yugoslavia           70              13             18
# 1          Austria           70              16             17
# 2           Sweden           84              15             18
# 3            Spain           88              13             22
# 4          Uruguay          140              16             26
# 5          Germany          126              16             35
# 6       Yugoslavia           89              16             32
# 7     Soviet Union           89              16             32
# 8          Uruguay           95              16             32
# 9           Brazil           97              16             38
# 10           Italy          102              16             38
# 11          France          146              24             52
# 12         Belgium          132              24             52
# 13         England          115              24             52
# 14        Bulgaria          141              24             52
# 15     Netherlands          171              32             64
# 16  Korea Republic          161              32             64
# 17        Portugal          147              32             64
# 18         Uruguay          145              32             64
# 19          Brazil          171              32             64
# 20         England          169              32             64

# %% [markdown]
# ## Adding the latest data (World Cup 2022)

# %%
new_data = {
    'Year': [2022],
    'Country': ['Qatar'],
    'Winner': ['Argentina'],
    'Runners-Up': ['France'],
    'Third': ['Croatia'],
    'Fourth': ['Morocco'],
    'GoalsScored':[172],
    'QualifiedTeams':[32],
    'MatchesPlayed':[64]
}

df = df._append(pd.DataFrame(new_data), ignore_index=True)
df
# Out:
#     Year       Country     Winner      Runners-Up        Third  \
# 0   1930       Uruguay    Uruguay       Argentina          USA
# 1   1934         Italy      Italy  Czechoslovakia      Germany
# 2   1938        France      Italy         Hungary       Brazil
# 3   1950        Brazil    Uruguay          Brazil       Sweden
# 4   1954   Switzerland    Germany         Hungary      Austria
# 5   1958        Sweden     Brazil          Sweden       France
# 6   1962         Chile     Brazil  Czechoslovakia        Chile
# 7   1966       England    England         Germany     Portugal
# 8   1970        Mexico     Brazil           Italy      Germany
# 9   1974       Germany    Germany     Netherlands       Poland
# 10  1978     Argentina  Argentina     Netherlands       Brazil
# 11  1982         Spain      Italy         Germany       Poland
# 12  1986        Mexico  Argentina         Germany       France
# 13  1990         Italy    Germany       Argentina        Italy
# 14  1994           USA     Brazil           Italy       Sweden
# 15  1998        France     France          Brazil      Croatia
# 16  2002   Korea/Japan     Brazil         Germany       Turkey
# 17  2006       Germany      Italy          France      Germany
# 18  2010  South Africa      Spain     Netherlands      Germany
# 19  2014        Brazil    Germany       Argentina  Netherlands
# 20  2018        Russia     France         Croatia      Belgium
# 21  2022         Qatar  Argentina          France      Croatia
#
#             Fourth  GoalsScored  QualifiedTeams  MatchesPlayed
# 0       Yugoslavia           70              13             18
# 1          Austria           70              16             17
# 2           Sweden           84              15             18
# 3            Spain           88              13             22
# 4          Uruguay          140              16             26
# 5          Germany          126              16             35
# 6       Yugoslavia           89              16             32
# 7     Soviet Union           89              16             32
# 8          Uruguay           95              16             32
# 9           Brazil           97              16             38
# 10           Italy          102              16             38
# 11          France          146              24             52
# 12         Belgium          132              24             52
# 13         England          115              24             52
# 14        Bulgaria          141              24             52
# 15     Netherlands          171              32             64
# 16  Korea Republic          161              32             64
# 17        Portugal          147              32             64
# 18         Uruguay          145              32             64
# 19          Brazil          171              32             64
# 20         England          169              32             64
# 21         Morocco          172              32             64

# %% [markdown]
# ## Year-to-year statistics

# %%
fig = px.line(
              df, x='Year', y=['GoalsScored', 'QualifiedTeams', 'MatchesPlayed'],
              labels={'value': 'Total'},
              line_dash_sequence=['solid', 'dash', 'dot']
              )

fig.update_layout(
                  title='FIFA World Cup Stats (1930-2022)',
                  title_x=0.5,
                  template='plotly_dark'
                  )
fig.show()
# Out:
# <div>                            <div id="2ef0d405-2ebd-4ab1-8235-ecd0314bb88a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ef0d405-2ebd-4ab1-8235-ecd0314bb88a")) {                    Plotly.newPlot(                        "2ef0d405-2ebd-4ab1-8235-ecd0314bb88a",                        [{"hovertemplate":"variable=GoalsScored\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GoalsScored","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"GoalsScored","orientation":"v","showlegend":true,"x":[1930,1934,1938,1950,1954,1958,1962,1966,1970,1974,1978,1982,1986,1990,1994,1998,2002,2006,2010,2014,2018,2022],"xaxis":"x","y":[70,70,84,88,140,126,89,89,95,97,102,146,132,115,141,171,161,147,145,171,169,172],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=QualifiedTeams\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"QualifiedTeams","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"QualifiedTeams","orientation":"v","showlegend":true,"x":[1930,1934,1938,1950,1954,1958,1962,1966,1970,1974,1978,1982,1986,1990,1994,1998,2002,2006,2010,2014,2018,2022],"xaxis":"x","y":[13,16,15,13,16,16,16,16,16,16,16,24,24,24,24,32,32,32,32,32,32,32],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=MatchesPlayed\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MatchesPlayed","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"MatchesPlayed","orientation":"v","showlegend":true,"x":[1930,1934,1938,1950,1954,1958,1962,1966,1970,1974,1978,1982,1986,1990,1994,1998,2002,2006,2010,2014,2018,2022],"xaxis":"x","y":[18,17,18,22,26,35,32,32,32,38,38,52,52,52,52,64,64,64,64,64,64,64],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0 ...

# %% [markdown]
# ## Which country has won the most?

# %%
most_win = df['Winner'].value_counts()

fig = px.bar(
             x=most_win.index,
             y=most_win.values,
             color=most_win.index,
             labels={'y': 'Number of Wins', 'x': 'Country'}
             )

fig.update_layout(
                  title='Fifa World Cup Wins (1930-2022)',
                  title_x=0.5,
                  xaxis_title='Country',
                  yaxis_title='Number of Wins',
                  template='plotly_dark'
                  )
fig.show()
# Out:
# <div>                            <div id="b6aeae21-0c7d-41bb-9b59-10468360b731" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6aeae21-0c7d-41bb-9b59-10468360b731")) {                    Plotly.newPlot(                        "b6aeae21-0c7d-41bb-9b59-10468360b731",                        [{"alignmentgroup":"True","hovertemplate":"color=Brazil\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Wins=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brazil","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Italy\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Wins=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"v","showlegend":true,"textposition":"auto","x":["Italy"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Germany\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Wins=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Argentina\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Wins=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Argentina","offsetgroup":"Argentina","orientation":"v","showlegend":true,"textposition":"auto","x":["Argentina"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Uruguay\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Wins=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Uruguay","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Uruguay","offsetgroup":"Uruguay","orientation":"v","showlegend":true,"textposition":"auto","x":["Uruguay"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=France\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Wins=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":["France"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=England\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Wins=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"England","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"England","offsetgroup":"England","orientation":"v","showlegend":true,"textposition":"auto","x":["England"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Spain\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Wins=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spain","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Spain","offsetgroup":"Spain","orientation":"v","showlegend":true,"textposition":"auto","x":["Spain"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overla ...

# %% [markdown]
# ## Which country has the highest frequency of participation in the finals?

# %%
finalists_df = pd.DataFrame({'Country': df[['Winner', 'Runners-Up']].stack(), 'Result': 'Finalist'})

finalists_counts = finalists_df['Country'].value_counts()

fig = px.bar(
             x=finalists_counts.index,
             y=finalists_counts.values,
             color=finalists_counts.index,
             labels={'y': 'Number of Finalist Appearances', 'x': 'Country'},
             title='Countries with Most Finalist Appearances (1930-2022)',
             template='plotly_dark'
            )

fig.update_layout(
                  title_x=0.5,
                  xaxis_title='Country',
                  yaxis_title='Number of Finalist Appearances'
                  )

fig.show()
# Out:
# <div>                            <div id="e154d3e8-d816-4f56-a08e-9af4f0a556d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e154d3e8-d816-4f56-a08e-9af4f0a556d5")) {                    Plotly.newPlot(                        "e154d3e8-d816-4f56-a08e-9af4f0a556d5",                        [{"alignmentgroup":"True","hovertemplate":"color=Germany\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Finalist Appearances=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Brazil\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Finalist Appearances=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brazil","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Argentina\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Finalist Appearances=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Argentina","offsetgroup":"Argentina","orientation":"v","showlegend":true,"textposition":"auto","x":["Argentina"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Italy\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Finalist Appearances=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"v","showlegend":true,"textposition":"auto","x":["Italy"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=France\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Finalist Appearances=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":["France"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Netherlands\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Finalist Appearances=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Netherlands","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Netherlands","offsetgroup":"Netherlands","orientation":"v","showlegend":true,"textposition":"auto","x":["Netherlands"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Uruguay\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Finalist Appearances=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Uruguay","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Uruguay","offsetgroup":"Uruguay","orientation":"v","showlegend":true,"textposition":"auto","x":["Uruguay"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Czechoslovakia\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Finalist Appearances=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Czechoslovakia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Czechoslovakia","offsetgroup":"Czechoslovakia","orientation":"v","showlegend":true,"textposition":"auto","x":["Czechoslovakia"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Hungary\u003cbr\u003eCountry=%{x}\u003cbr\u003eNumber of Finalist Appearances=%{y}\u003cextra\u003e\u003 ...

# %% [markdown]
# # Thank You :)
